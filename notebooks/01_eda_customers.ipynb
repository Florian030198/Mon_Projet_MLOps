# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys

# Astuce de pro : on dit au cahier de regarder dans le dossier parent pour trouver tes scripts
sys.path.append('../') 
from src.data.load_data import load_data

# On charge nos données en ajustant le chemin (car on est dans le dossier 'notebooks')
df = load_data('../data/raw/customers.csv')

# On affiche le tableau !
df.head()
# Out:
#    id     name  age       city
# 0   1    alice   28      Paris
# 1   2      bob   35       Lyon
# 3   3  charlie   42  Marseille

# %%
# On demande à Seaborn (notre peintre) de dessiner un graphique en barres
sns.barplot(data=df, x='city', y='age', palette='viridis')

plt.title("Moyenne d'âge par ville")
plt.show()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_6400\2716494488.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='city', y='age', palette='viridis')

# %%
# 1. Combien de lignes et de colonnes ? (Rows & columns)
print("Taille du tableau :", df.shape)

# 2. Quels sont les types de données et y a-t-il des trous ? (Data types & Missingness)
print("\n--- Infos générales ---")
df.info()

# 3. Y a-t-il des doublons ? (Duplicates)
print("\nDoublons trouvés :", df.duplicated().sum())
# Out:
# Taille du tableau : (3, 4)
#
# --- Infos générales ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   name    3 non-null      object
#  2   age     3 non-null      int64
#  3   city    3 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 120.0+ bytes
#
# Doublons trouvés : 0

# %%
# Pour les chiffres (Numerical) : la moyenne, le min, le max (pour repérer les valeurs extrêmes)
print("--- Statistiques des chiffres ---")
display(df.describe())

# Pour les textes (Categorical) : compter combien on a de clients par ville
print("\n--- Comptage des villes ---")
display(df['city'].value_counts())
# Out:
# --- Statistiques des chiffres ---
#         id   age
# count  3.0   3.0
# mean   2.0  35.0
# std    1.0   7.0
# min    1.0  28.0
# 25%    1.5  31.5
# 50%    2.0  35.0
# 75%    2.5  38.5
# max    3.0  42.0
# --- Comptage des villes ---
# city
# Paris        1
# Lyon         1
# Marseille    1
# Name: count, dtype: int64
